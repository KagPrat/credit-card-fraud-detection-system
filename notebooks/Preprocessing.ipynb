# %% [markdown]
# Standardize Amount and Time (the only non-PCA features), drop nulls, and split into train/test sets using StandardScaler from sklearn for this.
#
# # 1. Load the CSV

# %%
import pandas as pd
from pathlib import Path

csv_path = Path("../data/creditcardfraud/creditcard.csv")
df = pd.read_csv(csv_path)

print(df.shape)
print(df.dtypes)
print(df["Class"].value_counts())
# Out:
# (284807, 31)
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # 2. Inspect and clean

# %%
print(df.isnull().sum())          # confirm no nulls
print(df.duplicated().sum())      # check duplicates
print(df['Class'].value_counts(normalize=True))  # fraud = 0.17%
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
# 1081
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64
